# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib import rcParams # To set our defaults

# Load data
gapminder = pd.read_csv("./data/gapminder.csv")

# %%
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
sns.set_style("ticks")

# %%
# Set Default Fonts
rcParams["font.family"] = "sans-serif"
rcParams["font.sans-serif"] = ["Arial", "Tahoma"]

# Set Default font sizes
small_size = 12
medium_size = 14
bigger_size = 16

# Change the font size for individual elements
matplotlib.rc("font", size=small_size)          # controls default text sizes
matplotlib.rc("axes", titlesize=small_size)     # fontsize of the axes title
matplotlib.rc("axes", labelsize=medium_size)    # fontsize of the x and y labels
matplotlib.rc("xtick", labelsize=small_size)    # fontsize of the tick labels
matplotlib.rc("ytick", labelsize=small_size)    # fontsize of the tick labels
matplotlib.rc("legend", fontsize=small_size)    # legend fontsize
matplotlib.rc("axes", titlesize=medium_size)    # title fontsize

# %% [markdown]
# ## Continuous Data - Histogram

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
axes.hist(x = gapminder["life_exp"])

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()

# %% [markdown]
# ### Changing the bin sizes

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
# Plot the Data
axes.hist(gapminder["life_exp"],
          bins = 40) # NEW - Change the bin size (this specifies the number of bins)

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()

# %% [markdown]
# ### Changing the bin sizes programmatically

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
axes.hist(gapminder["life_exp"],
          bins = np.arange(start = 0,
                           stop = (gapminder["life_exp"].max() + 1),
                           step = 3) ) # NEW - Change the bin size by creating a suitable range and step using numpy

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()

# %% [markdown]
# ### Changing the orientation to horizontal

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
axes.hist(gapminder["life_exp"],
          bins = 15, # Change the bin size
          orientation = "horizontal")

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()

# %% [markdown]
# ### Changing colours in histograms

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
axes.hist(gapminder["life_exp"],
          bins = 15, # Change the bin size
          color='orange') # NEW - change the color here

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()

# %% [markdown]
# ### Change the outline colour of the bars

# %%
# Create our figure and our axes
figure, axes = plt.subplots(figsize=(6, 5))

# Plot the Data
axes.hist(gapminder["life_exp"],
          bins = 15, # Change the bin size
          color='orange',
          edgecolor='black') # NEW - change the color here

# Add Labels, Title and Captions

plt.suptitle("Frequency of Life Expectancy at Birth", horizontalalignment = "right")
plt.title("Data from Gapminder Dataset" , 
          fontname="Arial", size=12, x = 0.02)
figure.text(x=0.65, y=-0.03, s="Source: Gapminder", ha="left")
axes.set_xlabel("Life expectancy at birth in years ")
axes.set_ylabel("Count")

# Set xlim - the lowest x value - to 0
axes.set_xlim(0)

# Set Gridlines and colours

axes.grid(which = "both", axis = "y", color = (0.745, 0.745, 0.745))

axes.set_frame_on(False)
axes.set_axisbelow(True)

# Set Tick Colours to the same grey as our gridlines
axes.xaxis.set_tick_params(color=(0.745,0.745,0.745))
axes.yaxis.set_tick_params(color=(0.745,0.745,0.745))

plt.show()
